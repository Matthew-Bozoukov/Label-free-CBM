# %%
import json
import data_utils
import conceptset_utils

# %%
"""
CLASS_SIM_CUTOFF: Concenpts with cos similarity higher than this to any class will be removed
OTHER_SIM_CUTOFF: Concenpts with cos similarity higher than this to another concept will be removed
MAX_LEN: max number of characters in a concept

PRINT_PROB: what percentage of filtered concepts will be printed
"""

CLASS_SIM_CUTOFF = 0.85
OTHER_SIM_CUTOFF = 0.9
MAX_LEN = 30
PRINT_PROB = 1

dataset = "cifar100"
device = "cuda"

save_name = "data/concept_sets/{}_filtered_new.txt".format(dataset)

# %%
#EDIT these to use the initial concept sets you want
dataset="cifar10"
with open(f"data/concept_sets/gpt3_init/gpt3_{dataset}_important_new.json".format(dataset), "r") as f:
    important_dict = json.load(f)
with open(f"data/concept_sets/gpt3_init/gpt3_{dataset}_superclass_new.json".format(dataset), "r") as f:
    superclass_dict = json.load(f)
with open(f"data/concept_sets/gpt3_init/gpt3_{dataset}_around_new.json".format(dataset), "r") as f:
    around_dict = json.load(f)
    
with open(data_utils.LABEL_FILES[dataset], "r") as f:
    classes = f.read().split("\n")

# %%
concepts = set()

for values in important_dict.values():
    concepts.update(set(values))

for values in superclass_dict.values():
    concepts.update(set(values))
    
for values in around_dict.values():
    concepts.update(set(values))

print(len(concepts))
# Out:
# 399

# %%
concepts = conceptset_utils.remove_too_long(concepts, MAX_LEN, PRINT_PROB)
# Out:
# 41 higher ground clearance than typical cars
# 43 whisker pads and prominent facial structure
# 51 drivetrain (transmission/axles to drive the wheels)
# 41 smooth, moist skin (often green or brown)
# 46 visible eyes with forward or lateral placement
# 36 mouth with teeth (including canines)
# 35 engines (propellers or jet engines)
# 37 a short tail (often white underparts)
# 33 front grille and prominent bumper
# 60 often a separate chassis or frame beneath cab and cargo area
# 63 smooth, moist skin (no scales; may be green, brown, or mottled)
# 36 long, powerful hind legs for jumping
# 39 - large size relative to passenger cars
# 37 hunting gear (camouflage, rifle, bow)
# 35 robust, boxy/rectangular body shape
# 31 small, triangular nose (muzzle)
# 42 navigational features (bow, stern, rudder)
# 36 delivery paperwork or bill of lading
# 43 - a large, elongated body with a deep chest
# 45 means of propulsion (transmission/drivetrain)
# 43 upright ears (or detectable ear structures)
# 53 rear or side access to cargo area (tailgate or doors)
# 38 enclosed passenger compartment (cabin)
# 88 size noticeably larger than small boats (implying capacity to carry cargo or passengers)
# 33 hull or body that displaces water
# 60 a broad, flattened head with a wide mouth and prominent eyes
# 48 long hind legs adapted for jumping (webbed feet)
# 54 a horse-shaped head with large eyes and a broad muzzle
# 66 brownish coat (seasonal/dusky variations; often lighter underside)
# 39 vocalization ability (bark/whine/growl)
# 62 domestic dog size range and body proportions (varies by breed)
# 40 cockpit or flight deck (cockpit windows)
# 52 herbivorous dentition (adapted for grazing/browsing)
# 36 engines (jet turbines or propellers)
# 53 enclosed cargo area (bed) or open flatbed for hauling
# 45 - a slim, hoofed body with long, slender legs
# 34 a flowing mane and a tail (haired)
# 37 antlers on males (branched; seasonal)
# 46 barks, growls, or other dog-like vocalizations
# 33 fur/hair on clothing or furniture
# 35 eyes positioned forward on the head
# 55 visible superstructure or cabin(s) (bridge, wheelhouse)
# 36 four long, powerful legs with hooves
# 42 a bow (front) and stern (rear) orientation
# 47 presence of portholes or windows along the hull
# 53 tail (empennage: vertical and horizontal stabilizers)
# 35 digitigrade limbs (walking on toes)
# 31 ability to lay eggs (oviparity)
# 37 walks on all fours (quadrupedal gait)
# 53 often equipped with towing hitch or trailer connector
# 70 ability adapted for running (muscular hindquarters and limb structure)
# 45 means of propulsion (engines, sails, or oars)
# 49 a narrow, elongated head with large eyes and ears
# 31 a narrow head with a long snout
# 38 fuel (gasoline/diesel/electric charge)
# 62 herbivorous dentition (large, flat molars) and a grazing mouth
# 41 whisker pads and a small, triangular nose
# 35 toys (string, balls, laser pointer)
# 44 teeth adapted for biting (incisors, canines)
# 41 a long neck and proportionally sized head
# 43 deck(s) and superstructure (bridge, cabins)
# 37 rutting season signs (males sparring)
# 71 brownish coat (with seasonal color variations; may have spots in fawns)
# 56 a wide mouth with a protrusible tongue for catching prey
# 51 heavy-duty wheels/tires and higher ground clearance
# 49 visible cargo tie-down points or cargo restraints
# 58 designed for operation on open water (sea, river, or lake)
# 43 predators (wolves, coyotes, mountain lions)
# 42 strong, noticeable front grille and bumper
# 51 engine or motor (mounted front, rear, or underbody)
# 47 no tail (adult frogs lack a long external tail)
# 38 walk/run gait (quadrupedal locomotion)
# 46 control surfaces (ailerons, elevators, rudder)
# 44 steering mechanism (steering wheel/controls)
# 59 relatively large size compared with common domestic animals
# 75 means of propulsion (smokestack, funnel, mast/sails, or engines/propellers)
# 59 visible cargo-carrying capacity (load bed, box, or flatbed)
# 41 four or more wheels with heavy-duty tires
# 50 - a stocky, compact body (often short and rounded)
# 36 ability to carry cargo or passengers
# 38 forward-facing eyes (binocular vision)
# 64 open or enclosed cargo area (bed or container) for hauling goods
# 32 camouflage/spotting (esp. fawns)
# 44 almond-shaped eyes with vertical slit pupils
# 43 seating for driver (and usually passengers)
# 60 prominent front cab with seating for driver (often elevated)
# 39 retractable (or semi-retractable) claws
# 52 robust frame and suspension for carrying heavy loads
# 31 a toy (ball, chew toy, frisbee)
# 35 steering mechanism (steering wheel)
# 55 navigational features (mast, antenna, flags, or lights)
# 41 alert posture and graceful, bounding gait
# 37 flexible, agile body with a long tail
# 49 - a large elongated hull (long, boat-shaped body)
# 31 seats for driver and passengers
# 49 engine or motor (internal combustion or electric)
# 50 - large size relative to boats (varies by context)
# 399 302

# %%
concepts = conceptset_utils.filter_too_similar_to_cls(concepts, classes, CLASS_SIM_CUTOFF, device, PRINT_PROB)
# Out:
# 302
# 302
# Class:automobile - Concept:vehicle, sim:0.904 - Deleting vehicle
#
# Class:bird - Concept:birds, sim:0.891 - Deleting birds
#
# Class:bird - Concept:other birds, sim:0.878 - Deleting other birds
#
# Class:deer - Concept:herd or other deer, sim:0.885 - Deleting herd or other deer
#
# Class:dog - Concept:animal, sim:0.855 - Deleting animal
#
# Class:dog - Concept:pet, sim:0.871 - Deleting pet
#
# Class:frog - Concept:frogs (other frogs), sim:0.900 - Deleting frogs (other frogs)
#
# Class:frog - Concept:other frogs, sim:0.890 - Deleting other frogs
#
# Class:truck - Concept:jet fuel truck, sim:0.857 - Deleting jet fuel truck
#
# 293

# %%
concepts = conceptset_utils.filter_too_similar(concepts, OTHER_SIM_CUTOFF, device, PRINT_PROB)
# Out:
# - a road - - road , sim:0.9454 - Deleting - road
# - fur or hair - fur or hair , sim:0.9563 - Deleting fur or hair
# - fur or hair - fur or hair (coat) , sim:0.9133 - Deleting fur or hair (coat)
# - fur or hair - fur/hair , sim:0.9349 - Deleting fur/hair
# - mammal - mammal , sim:0.9090 - Deleting - mammal
# - vehicle - -vehicle , sim:1.0000 - Deleting -vehicle
# a bowl (food or water) - a bowl (food/water) , sim:0.9930 - Deleting a bowl (food/water)
# a bowl (food or water) - a food bowl , sim:0.9199 - Deleting a bowl (food or water)
# a driver - driver , sim:0.9401 - Deleting a driver
# a food bowl - food bowl , sim:0.9634 - Deleting a food bowl
# a license plate - license plate , sim:0.9590 - Deleting license plate
# a long tail - a short tail , sim:0.9102 - Deleting a long tail
# a park/yard - a yard/park , sim:0.9892 - Deleting a yard/park
# a scratching post - scratching post , sim:0.9661 - Deleting scratching post
# a short tail - a tail , sim:0.9235 - Deleting a short tail
# a snout/muzzle with nose - nose (snout) , sim:0.9058 - Deleting a snout/muzzle with nose
# a tail - tail , sim:0.9428 - Deleting tail
# a trailer - trailer , sim:0.9275 - Deleting trailer
# artifact - physical artifact , sim:0.9011 - Deleting physical artifact
# beak - beak/bill , sim:0.9078 - Deleting beak/bill
# binoculars - binoculars/scopes , sim:0.9158 - Deleting binoculars/scopes
# cockpit - cockpit (pilot/control area) , sim:0.9076 - Deleting cockpit (pilot/control area)
# doors for entry and exit - doors for entry/exit , sim:0.9922 - Deleting doors for entry and exit
# feathers - feathers (down) , sim:0.9143 - Deleting feathers
# flight attendant - flight attendants , sim:0.9312 - Deleting flight attendants
# food bowl - water bowl , sim:0.9080 - Deleting water bowl
# fuselage (long body) - fuselage (main body) , sim:0.9618 - Deleting fuselage (main body)
# insects - insects (flies, mosquitoes) , sim:0.9126 - Deleting insects (flies, mosquitoes)
# landing gear - landing gear (wheels or skids) , sim:0.9054 - Deleting landing gear (wheels or skids)
# large, pointed ears - pointed ears , sim:0.9499 - Deleting large, pointed ears
# means of transportation - transport , sim:0.9007 - Deleting means of transportation
# migration flocks - migration/flock , sim:0.9399 - Deleting migration/flock
# ropes (lines) - ropes (or lines) , sim:0.9852 - Deleting ropes (lines)
# transport - transportation , sim:0.9618 - Deleting transport
# transportation - transportation device , sim:0.9080 - Deleting transportation device
# tree - trees , sim:0.9274 - Deleting trees
# two legs with claws or talons - two legs with claws/feet , sim:0.9420 - Deleting two legs with claws or talons
# 256

# %%
with open(save_name, "w") as f:
    f.write(concepts[0])
    for concept in concepts[1:]:
        f.write("\n" + concept)
